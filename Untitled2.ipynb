# %% [markdown]
# <a href="https://colab.research.google.com/github/aleiba24/Phyton-Data-Base/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# cargar el archivo
url = '/content/MEDICAMENTOS_POS_20240413.csv'
df = pd.read_csv(url)

# mostrar las primeras filas
#print(df.head())

#calcular est descript
#print (df.describe())

#filtrar datos
#filtro = df['principioactivo'] == 'HIDROCLOROTIAZIDA'
#datos_filtrados = df[filtro]
#print(datos_filtrados)

#columnas = df.columns
#print(columnas)


#revisar cant de columnas y filas
#shape = df.shape
#print (shape)

#mostrar cola
#tail = df.tail
#print (tail)

#valores unicos
#unique = df['producto'].unique()
#df['producto'].drop_duplicates()
#print(unique)

#contar
#count_unique_values = df['producto'].value_counts()
#print(count_unique_values)

#estadistica descriptiva
#print(df['expediente'].mean())

#resumen
#print(df.info())

#elementos aleatorios
#print(df.sample(5))

#construir dataframe del dataframe no traer todas las columnas siempre
#df[['producto','unidad']]

#nueva columna
#df['nuevo'] = df ['producto'].apply(lambda x: len(str(x)))
#print(df)

# eliminar columna
#df.drop('unidad', axis ='columns')
df.drop (1, axis='index')
# Out:
#             atc                                    principioactivo  \
# 0       A02BC01  OMEPRAZOL (EQUIVALENTE A 8.5% DE OMEPRAZOL POR...
# 2       S01BC10                                         NEPAFENACO
# 3       C01BC03                            PROPAFENONA CLORHIDRATO
# 4       G04CB02                                        DUTASTERIDA
# 5       S01XA20                                          GLICERINA
# ...         ...                                                ...
# 147385  B05BB01                      CLORURO DE CALCIO DIHIDRATADO
# 147386  N02BE51                                    CAFEINA ANHIDRA
# 147387  H05BX02                                       PARICALCITOL
# 147388  N02BE75  ACETAMINOFEN COMPAP WSE95% EQUIVALENTE A ACETA...
# 147389  G03AC03                         LEVONORGESTREL MICRONIZADO
#
#                                            descripcionatc  \
# 0                                               OMEPRAZOL
# ...
